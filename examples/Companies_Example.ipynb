# %%
using YahooFinanceAPI

# %%
companies = fetchCompanies(IndustryCodes.Copper);
println(companies)
# Out:
# http://biz.yahoo.com/p/csv/131conameu.csv
# Any["
# Description" "1-Day Price Chg %" "Market Cap" "P/E" "ROE %" "Div. Yield %" "Debt to Equity" "Price to Book" "Net Profit Margin (mrq)" "Price To Free Cash Flow (mrq)"
#     "Basic Materials" 1.251 "201509.38B" 12.805 11.916 4.034 44.232 2.01 5.7 40.985
#     "Copper" 2.7 "851.85B" 17.2 15.7 3.659 75.243 2.38 15.8 -69.9
#     "A-Cap Resources Ltd" 0.0 "18.41M" "NA" -5.34 "NA" "NA" 0.442 "NA" -27.698
#     "ABC Gas (International) Ltd" "NA" "NA" "NA" 6.252 "NA" 80.209 "NA" 7.344 "NA"
#     "Aditya Birla Minerals Ltd" 5.56 "59.54M" "NA" -40.444 "NA" 0.194 0.178 "NA" -0.792
#     "Aditya Birla Minerals Ltd" "NA" "NA" "NA" -40.444 "NA" 0.194 "NA" "NA" "NA"
#     "Admiralty Resources NL" 0.0 "28.79M" "NA" -16.845 "NA" 14.792 1.304 "NA" -48.791
#     "Admiralty Resources NL" "NA" "NA" "NA" -16.845 "NA" 14.792 "NA" "NA" "NA"
#     "Advance Sct Ltd" "NA" "0.00M" "NA" "NA" "NA" 350.745 "NA" 5.177 0.0
# ...
