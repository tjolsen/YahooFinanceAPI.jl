# %%
using YahooFinanceAPI

# %%
companies = fetchCompanies(IndustryCodes.Copper);
println(companies)
# Out:
# http://biz.yahoo.com/p/csv/131conameu.csv
# Any["
# Description" "1-Day Price Chg %" "Market Cap" "P/E" "ROE %" "Div. Yield %" "Debt to Equity" "Price to Book" "Net Profit Margin (mrq)" "Price To Free Cash Flow (mrq)"
#     "Basic Materials" -
# 1.362 "214913.70B" 17.48 6.623 3.565 46.339 2.915 0.999 -29.688
#     "Copper" -0.028 "1030.43B" 0.0 0.0 1.204 100.664 2.29 -19.0 -20.4
#     "A-Cap Resources Ltd" 0.0 "7.50M" "NA" -6.471 "NA" "NA" 0.171 "NA" -5.268
#     "ABC Gas (International) Ltd" 5.0 "44.10M" 30.33 "NA" "NA" 67.919 1.81 0.194 "NA"
#     "Aditya Birla Minerals Ltd" 0.0 "56.41M" "NA" -54.942 "NA" 0.449 0.198 -103.939 0.837
#     "Aditya Birla Minerals Ltd" "NA" "NA" "NA" -54.942 "NA" 0.449 "NA" -103.939 "NA"
#     "Admiralty Resources NL" 0.0 "17.27M" "NA" -17.147 "NA" 14.579 0.947 "NA" -32.102
#     "Admiralty Resources NL" "NA" "NA" "NA" -17.147 "NA" 14.579 "NA" "NA" "NA"
#     "Advance Sct Ltd" 0.0 "14.93M" "NA" -52.53 "NA" 273.586 "NA" -7.635 -3.663
# ...
