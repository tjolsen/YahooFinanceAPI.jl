# %%
using YahooFinanceAPI

# %%
companies = fetchCompanies(IndustryCodes.Agricultural_Chemicals);
println(companies)
# Out:
# http://biz.yahoo.com/p/csv/112conameu.csv
# Any["
# Description" "1-Day Price Chg %" "Market Cap" "P/E" "ROE %" "Div. Yield %" "Debt to Equity" "Price to Book" "Net Profit Margin (mrq)" "Price To Free Cash Flow (mrq)"
#     "Basic Materials" 1.251 "201509.38B" 12.805 11.916 4.034 44.232 2.01 5.7 40.985
#     "Agricultural Chemicals" 0.622 "1201.87B" 16.9 21.6 2.598 79.372 5.56 14.1 49.4
#     "Adarsh Plant Protect Ltd" "NA" "NA" "NA" -17.932 "NA" 109.246 "NA" -11.33 "NA"
#     "African Potash Ltd" 0.0 "299.24M" "NA" -6.474 "NA" "NA" 22.826 "NA" -587.543
#     "Agrium Inc" "NA" "NA" "NA" 11.826 "NA" 71.521 "NA" 1.712 "NA"
#     "Agrium Inc" 1.07 "19.45B" 25.593 11.826 "NA" 71.521 2.817 1.712 -22.213
#     "Agrium Inc." 1.5 "15.60B" 20.529 11.826 2.9 71.521 2.26 1.712 -17.819
#     "Aimco Pesticides Ltd" "NA" "NA" "NA" 87.072 "NA" 228.947 "NA" -2.463 "NA"
#     "American Vanguard Corp." 0.25 "354.55M" 104.103 1.036 0.7 36.661 1.362 1.022 -60.094
# ...
