# %%
using YahooFinanceAPI

# %%
companies = fetchCompanies(IndustryCodes.Wireless_Communications);
println(companies)
# Out:
# http://biz.yahoo.com/p/csv/840conameu.csv
# Any["
# Description" "1-Day Price Chg %" "Market Cap" "P/E" "ROE %" "Div. Yield %" "Debt to Equity" "Price to Book" "Net Profit Margin (mrq)" "Price To Free Cash Flow (mrq)"
#     "Technology" 0.56 "132660.77B" 17.433 26.887 3.046 193.34 -0.018 21.736 43.746
#     "Wireless Communications" 0.21 "66890.99B" 4.8 30.9 3.472 340.803 3.51 30.2 12.0
#     "Ace Achieve Infocom Ltd" "NA" "NA" "NA" 5.135 "NA" 53.27 "NA" 12.886 "NA"
#     "Acotel Group" -2.32 "50.31M" "NA" -30.577 "NA" 16.694 1.574 -29.778 "NA"
#     "Acropolis Telecom" "NA" "NA" "NA" -76.901 "NA" 34.937 "NA" -0.565 "NA"
#     "AcrossAsia Ltd." -7.69 "514.80M" "NA" "NA" "NA" 32.897 5.0 0.208 "NA"
#     "AdEPT Telecom PLC" 0.0 "3.42B" 2622.88 13.318 "NA" 46.656 310.12 6.73 3931.81
#     "Advanced Info Service PLC" "NA" "NA" "NA" 77.629 "NA" 79.057 "NA" 22.544 "NA"
#     "Advanced Info Service PLC" "NA" "NA" "NA" 77.629 "NA" 79.057 "NA" 22.544 "NA"
# ...
